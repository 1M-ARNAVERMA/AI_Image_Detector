# %%
import os

BASE = "../dataset"

for category in ["real", "ai", "edited"]:
    path = os.path.join(BASE, category)
    files = os.listdir(path)

    print(f"{category.upper()} IMAGES: {len(files)}")
# Out:
# REAL IMAGES: 10000
# AI IMAGES: 10000
# EDITED IMAGES: 5123
