# %%
import numpy as np
import joblib
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X = np.load("../results/X_train_pca.npy")
y = np.load("../results/y_train.npy")

svm = SVC(kernel="rbf", C=5, gamma="scale", probability=True)
svm.fit(X, y)

pred = svm.predict(X)
print(classification_report(y, pred))

joblib.dump(svm, "../models/svm_model.pkl")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      7000
#            1       0.90      0.89      0.89      7000
#            2       1.00      1.00      1.00      3586
#
#     accuracy                           0.91     17586
#    macro avg       0.93      0.93      0.93     17586
# weighted avg       0.91      0.91      0.91     17586
# ['../models/svm_model.pkl']
