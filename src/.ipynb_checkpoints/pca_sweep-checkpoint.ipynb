# %%
import numpy as np
from sklearn.decomposition import PCA

X = np.load("../results/X_train.npy")

for n in [100, 200, 300, 500, 800]:
    pca = PCA(n_components=n, random_state=42)
    X_pca = pca.fit_transform(X)
    var = sum(pca.explained_variance_ratio_)
    print(f"PCA components: {n} → Explained variance: {var:.3f}")
# Out:
# PCA components: 100 → Explained variance: 0.733
# PCA components: 200 → Explained variance: 0.756
# PCA components: 300 → Explained variance: 0.776
# PCA components: 500 → Explained variance: 0.813
# PCA components: 800 → Explained variance: 0.858

# %%
import numpy as np
from sklearn.decomposition import PCA

X = np.load("../results/X_train.npy")

for n in [100, 200, 300, 500, 800]:
    pca = PCA(n_components=300, random_state=42)
    X_pca = pca.fit_transform(X)
    var = sum(pca.explained_variance_ratio_)
    print(f"PCA components: {n} → Explained variance: {var:.3f}")
# Out:
# PCA components: 100 → Explained variance: 0.776
# PCA components: 200 → Explained variance: 0.776
# PCA components: 300 → Explained variance: 0.776
# PCA components: 500 → Explained variance: 0.776
# PCA components: 800 → Explained variance: 0.776
